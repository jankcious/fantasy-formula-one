# %%
from random import randint

# %%
# ?randint()

# %%
dude
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e51b55b7c71a> in <module>()
# ----> 1 dude
#
# NameError: name 'dude' is not defined

# %%
import numpy as np
import pandas as pd

# %%
rolls = np.random.random_integers(1, 20, 10000000)
rolls2 = np.random.random_integers(1, 20, 10000000)
matrix = pd.DataFrame(rolls)
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning: This function is deprecated. Please call randint(1, 20 + 1) instead
#   if __name__ == '__main__':
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: DeprecationWarning: This function is deprecated. Please call randint(1, 20 + 1) instead
#   from ipykernel import kernelapp as app

# %%
matrix['roll2'] = rolls2

# %%
matrix
# Out:
#           0  roll2
# 0        18     18
# 1        18      5
# 2         5     15
# 3         7     12
# 4         9      6
# 5         6      4
# 6         9      6
# 7        20      3
# 8         4     11
# 9         7      3
# 10       20      5
# 11        1     11
# 12       11     18
# 13       13      1
# 14       19     18
# 15       19      1
# 16       16      2
# 17        6      9
# 18       13     10
# 19        6      5
# 20        6     10
# 21        3     16
# 22       10      2
# 23       19     16
# 24        5      2
# 25        8     19
# 26        7     11
# 27        1      3
# 28       13      5
# 29        5     15
# ...      ..    ...
# 9999970   6     17
# 9999971  17     16
# 9999972  19      6
# 9999973   7      1
# 9999974   4      8
# 9999975  12      6
# 9999976   1     17
# 9999977   8      9
# 9999978   3      7
# 9999979  12      7
# 9999980  15     19
# 9999981  14     13
# 9999982   2     10
# 9999983  20      9
# 9999984   7      3
# ...

# %%
matrix.columns = ['roll1', 'roll2']
matrix
# Out:
#          roll1  roll2
# 0           18     18
# 1           18      5
# 2            5     15
# 3            7     12
# 4            9      6
# 5            6      4
# 6            9      6
# 7           20      3
# 8            4     11
# 9            7      3
# 10          20      5
# 11           1     11
# 12          11     18
# 13          13      1
# 14          19     18
# 15          19      1
# 16          16      2
# 17           6      9
# 18          13     10
# 19           6      5
# 20           6     10
# 21           3     16
# 22          10      2
# 23          19     16
# 24           5      2
# 25           8     19
# 26           7     11
# 27           1      3
# 28          13      5
# 29           5     15
# ...        ...    ...
# 9999970      6     17
# 9999971     17     16
# 9999972     19      6
# 9999973      7      1
# 9999974      4      8
# 9999975     12      6
# 9999976      1     17
# 9999977      8      9
# 9999978      3      7
# ...

# %%
# %timeit matrix[(matrix['roll1'] == 19) | (matrix['roll1'] == 20) | (matrix['roll2'] == 19) | (matrix['roll2'] == 20) | \
       (matrix['roll1'] == matrix['roll2'])].count() / 10000000 * 100
# Out:
# 1 loops, best of 3: 282 ms per loop

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
fig = plt.figure(figsize=(16,12))
ax = fig.add_subplot(111)
ttl = 'Fantasy Driver Points'
ax.set_axis_bgcolor('#ffff00')

# %%
df = pd.DataFrame(columns=('This', 'That'))
df['That'] = ['HAM', 'RAI', 'EXO', 'RCI', 'VGA', 'HAR', 'VET']
df['This'] = [1, 2, 3, 4, 5, 6, 7]
df
# Out:
#    This That
# 0     1  HAM
# 1     2  RAI
# 2     3  EXO
# 3     4  RCI
# 4     5  VGA
# 5     6  HAR
# 6     7  VET

# %%
df['This'].plot(kind='bar', figsize = (10,10), edgecolor='#000000', linewidth=5)
plt.

# %%
import pandas as pd

# %%
df = pd.read_csv('driver_info.csv', encoding='ISO-8859-1')
