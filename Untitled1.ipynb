# %%
import f1

# %%
China = f1.Race('China')

# %%
from f1 import Team
from f1 import Race

# %%
Azerbaijan = Race('Azerbaijan')

# %%
# ?Azerbaijan.update_grid()

# %%
China.grid_position
# Out:
# {'Carlos Sainz Jr.': 8,
#  'Daniel Ricciardo': 2,
#  'Daniil Kvyat': 6,
#  'Esteban Gutiérrez': 18,
#  'Felipe Massa': 10,
#  'Felipe Nasr': 16,
#  'Fernando Alonso': 11,
#  'Jenson Button': 12,
#  'Jolyon Palmer': 19,
#  'Kevin Magnussen': 17,
#  'Kimi Räikkönen': 3,
#  'Lewis Hamilton': 22,
#  'Marcus Ericsson': 15,
#  'Max Verstappen': 9,
#  'Nico Hülkenberg': 13,
#  'Nico Rosberg': 1,
#  'Pascal Wehrlein': 21,
#  'Rio Haryanto': 20,
#  'Romain Grosjean': 14,
#  'Sebastian Vettel': 4,
#  'Sergio Pérez': 7,
#  'Valtteri Bottas': 5}

# %%
China.push_to_season()
# Out:
#                                         Team Qualifying  Grid Eff_Grid Finish  \
# Sebastian Vettel                     Ferrari          4     4        4      2
# Kimi Räikkönen                       Ferrari          3     3        3      5
# Sergio Pérez            Force India-Mercedes          7     7        7     11
# Nico Hülkenberg         Force India-Mercedes         10    13       13     15
# Esteban Gutiérrez               Haas-Ferrari         18    18       18     14
# Romain Grosjean                 Haas-Ferrari         14    14       14     19
# Pascal Wehrlein                 MRT-Mercedes         21    21       21     18
# Rio Haryanto                    MRT-Mercedes         20    20       20     21
# Fernando Alonso                McLaren-Honda         12    11       11     12
# Jenson Button                  McLaren-Honda         13    12       12     13
# Nico Rosberg                        Mercedes          1     1        1      1
# ...
